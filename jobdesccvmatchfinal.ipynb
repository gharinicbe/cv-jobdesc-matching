# %%
import PyPDF2
import pandas as pd
import numpy as np

from textblob import TextBlob
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import os
import re
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

dataset_root_folder = './Resumespdf/data/data'
dataset = pd.read_csv('./jobdesc_data.csv')

def text_cleaning(text):
    
    # Remove HTML tags 
    cleaned_text = re.sub(r'<.*?>', ' ', text)
    
    # Remove non-english characters, punctuation,special characters, digits, continous underscores and extra whitespace
    cleaned_text = re.sub('[^a-zA-Z]', ' ', cleaned_text)
    cleaned_text = re.sub(r'[^\w\s]|_', ' ', cleaned_text)
    cleaned_text = re.sub(r'\d+', ' ', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    cleaned_text=re.sub('http\S+\s', " ", cleaned_text)
    
    
    
    # Convert to lowercase
    cleaned_text = cleaned_text.lower()
    
    # Tokenize the cleaned text
    words = word_tokenize(cleaned_text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    
    # Tokenize the cleaned text
    words = word_tokenize(cleaned_text)
    
    # Apply stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    cleaned_text = ' '.join(stemmed_words)
    
    return cleaned_text

def extract_specific_lines(pdf_file_path):
    sents = []
    with open(pdf_file_path, "rb") as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        for page in pdf_reader.pages:
                       
            text = page.extract_text()
            # Clean extracted text
            cleaned_value = text_cleaning(text)
            # Use TextBlob to split sentences
            blob = TextBlob(cleaned_value)
            sents.extend(blob.sentences)
            
    # Define keywords to search for
    keyword_lines = []
    
    # Iterate through lines and check for keywords
    for sent in sents:
        sent = str(sent)  # Convert TextBlob line to a string
        #print ('sent: ', sent)
        words = TextBlob(sent.lower()).words 
        
        if "educ" not in words and "skill" not in words:
            continue
        
        keyword_lines.append(sent)
        
        #print(keyword_lines)
     
    return keyword_lines

data = []
resumes_list =[]
for category_folder in os.listdir(dataset_root_folder):
    count = 0
    category_folder_path = os.path.join(dataset_root_folder, category_folder)
    if os.path.isdir(category_folder_path):
        for filename in os.listdir(category_folder_path):
            if filename.endswith(".pdf"):
                pdf_path = os.path.join(category_folder_path, filename)
                #for every resume extract only the specific lines with keywords
                resume_lines = extract_specific_lines(pdf_path)
                if len(resume_lines) <=0:
                    continue
                #append the resume_lines as strings in reasumes_list
                resumes_list.append(resume_lines[0])                                
                category = category_folder
                filename = filename 
                #append category_folder, filename, resume_lines for creating a pandas dataframe
                data.append([category_folder, filename, resume_lines])
                count += 1
                if count == 2:
                    break
# Create a Pandas DataFrame using the data list
df1 = pd.DataFrame(data, columns=["Category", "File", "Line"])

# Select the first 10 job descriptions and company names
job_descriptions = dataset["job_description"][:10]
companies = dataset["company_name"][:10]

# Create a new DataFrame and set the index
df = pd.DataFrame({'Job Description': job_descriptions})
df.index = companies
#print(df.head())
#Covert Job Description in the dataframe to list of strings and clean
job_description = list(df['Job Description'])
job_description_cleaned = []
for job in job_description:
    job_description_cleaned.append(text_cleaning(job))
#print(job_description_cleaned)


#load model

model  = SentenceTransformer("bert-base-uncased")

# embedding of list

embeddings =  model.encode(resumes_list)
embeddingsSearched = model.encode(job_description_cleaned)

#finding similarity
similarity = cosine_similarity(embeddingsSearched, embeddings)

# Iterate through job descriptions
for i, job_description in enumerate(job_description_cleaned):
    print(f"Job Description {i + 1}:\n {df.index[i]}:\n{df['Job Description'][i]}\n")
    
    # Get similarity scores for this job description
    similarity_scores = similarity[i]
    
    # Sort CVs by similarity score (highest to lowest)
    sorted_indices = similarity_scores.argsort()[::-1]
    
    # List the top 5 CVs for this job description
    top_cv_indices = sorted_indices[:5]
    
    print("Top 5 CVs:")
    for j, cv_index in enumerate(top_cv_indices, start=1):
        print("cv_index= ",cv_index)
        print(f"CV {j} (Similarity Score: {similarity_scores[cv_index]}):")
        print(f"Category: {df1['Category'][cv_index]}")
        print(f"File Name: {df1['File'][cv_index]}")
        print(f"Resume Text: {df1['Line'][cv_index]}\n")


# Now, resumes listed are top 5 resumes (as text) for each job description,
# and the code prints them alongside the job descriptions.
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Harini
# [nltk_data]     Balaji\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Harini
# [nltk_data]     Balaji\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# No sentence-transformers model found with name C:\Users\Harini Balaji/.cache\torch\sentence_transformers\bert-base-uncased. Creating a new one with MEAN pooling.
# Job Description 1:
#  Googleminimum qualifications
# bachelors degree or equivalent practical experience years of experience in saas or productivity tools businessexperience managing enterprise accounts with sales cycles
# preferred qualifications
#  years of experience building strategic business partnerships with enterprise customersability to work through and with a reseller ecosystem to scale the businessability to plan pitch and execute a territory business strategyability to build relationships and to deliver results in a crossfunctionalmatrixed environmentability to identify crosspromoting and uppromoting opportunities within the existing account baseexcellent account management writtenverbal communication strategic and analyticalthinking skills
# about the job
# as a member of the google cloud team you inspire leading companies schools and government agencies to work smarter with google tools like google workspace search and chrome you advocate the innovative power of our products to make organizations more productive collaborative and mobile your guiding light is doing whats right for the customer you will meet customers exactly where they are at and provide them the best solutions for innovation using your passion for google products you help spread the magic of google to organizations around the world
# the google workspace team helps customers transform and evolve their business through the use of googles productivity collaboration and content management suite of applications as part of an entrepreneurial team in this growing business you will help shape the future of businesses use technology to connect with customers employees and partners
# as a google workspace sales specialist you will be responsible for maintenance and expansion of google workspace business growth across the region with customers in this role youll create and execute the strategy and provide unique insights on applying google workspace solutions to enterprisesyou will build an excellent pipeline and work with the account teams to build out the customer solution and establish partnerships you will strategize with partners to increase account and territory business growth you will work directly with customers coordinate internal resources and construct successful strategies at account and territory level
# google cloud accelerates organizations ability to digitally transform their business with the best infrastructure platform industry solutions and expertise we deliver enterprisegrade solutions that leverage googles cuttingedge technology  all on the cleanest cloud in the industry customers in more than  countries and territories turn to google cloud as their trusted partner to enable growth and solve their most critical business problems
#
# Top 5 CVs:
# cv_index=  40
# CV 1 (Similarity Score: 0.9658176898956299):
# Category: INFORMATION-TECHNOLOGY
# File Name: 10089434.pdf
# Resume Text: ['inform technolog technician summari versatil system administr possess superior troubleshoot skill network issu end user problem network secur experienc server manag system analysi offer depth understand infrastructur area detail orient independ focus take systemat approach solv complex problem demonstr except technic knowledg skill work variou team achiev share goal object highlight activ directori group polici object powershel vbscript microsoft exchang vmware experi new technolog product research offic azur storag manag enterpris backup manag disast recoveri experi inform technolog technician aug current compani name citi state migrat manag user account microsoft offic exchang onlin creat manag virtual machin system domain control activ directori feder servic adf microsoft window azur iaa creat manag storag microsoft window azur iaa instal configur storsimpl iscsi cloud array staa baa instal configur test twinstrata iscsi cloud array staa baa collabor project plan offic migrat develop detail specif offic migrat includ busi case document cost benefit analys technic diagram work flow document receiv train mvc visual studio use net framework develop applic use html css instal configur support linux machin open wi fi network project compil gener statist inform concern wireless network traffic use cacti configur wireless lan router network secur access instal configur wireless certif develop detail specif acquisit enterpris backup system includ system design busi case document cost benefit analysi technic diagram work flow document review evalu analyz department polici guidelin procedur standard manag staff develop test script accept unit system test hyperion phase miamibiz phase develop qualiti assur test plan hyperion phase miamibiz phase debug log error hyperion miamibiz use team foundat server tf particip variou phase project life cycl determin requir design conceptu test implement deploy releas hyperion miamibiz project collabor project plan hyperion miamibiz prepar present document demonstr hyperion miamibiz function design monitor network traffic compil gener statist inform use solar wind collabor disast recoveri plan procedur research evalu recommend new hardwar new softwar commun defin system design requir new exist system applic research evalu recommend test implement third parti softwar util plan design network infrastructur chang ad remov server applianc network logic flow review evalu analyz exist system applic viabil manag staff administ maintain share file server review server log troubleshoot issu schedul appli hot fix secur patch server infrastructur includ oper system applic softwar review system report sccm system center configur manag resolv servic request escal help desk technician troubleshoot analyz system problem root caus analysi give particip train educ program explain upgrad end user migrat user document local comput storag share file server configur support maintain file share use distribut file system df manag implement test enterpris backup infrastructur system symantec verita netbackup symantec backup exec system recoveri livest vranger backup server manag configur support datadomain storag configur support microsoft window server instal configur support microsoft window window microsoft offic', 'instal configur support mcafe anti viru softwar server migrat exchang infrastructur exchang exchang exchang exchang support server virtual infrastructur use vmware vsphere instal configur test veeam virtual machin backup softwar virtual desktop infrastructur vdi review system report system center configur manag sccm administ maintain symantec enterpris vault server manag activ directori domain control dc creat maintain group polici object gpo microsoft activ directori configur support microsoft exchang activ sync devic appl io android mobil oper system configur support blackberri devic blackberri enterpris server receiv exchang email develop test design implement applic script use languag com ...
#
# cv_index=  33
# CV 2 (Similarity Score: 0.96409672498703):
# Category: FINANCE
# File Name: 11441764.pdf
# Resume Text: ['financ manag summari pro activ result orient deadlin driven broad experi aspect account financi manag solid plan organiz skill coordin aspect project incept complet see big pictur plan appropri strategi achiev result well disciplin proven abil manag multipl assign effici extrem pressur meet tight deadlin schedul strong team builder facilit creat atmospher encourag individu growth among account profession maxim potenti product ascertain need goal streamlin exist oper envis new concept look area improv follow develop direct clearli effect commun direct commit peopl action timelin transform complex inform easili understood format highlight sap dynam ax sbt ifr jd edward ma great plain quickbook access sa sql ms offic includ excel ultipro adp report smith e time heavi timesav ezlabor easypay comprehens experi organiz engin inventori control purchas report process improv financi manag analysi quarterli year end audit budget forecast prepar administr gener account hr payrol staff manag busi analysi gaap jsox iso sox experi financ manag compani name citi state provid financi report three plant region manag day day oper includ overse account function procur annual budget forecast payrol compli sox work corpor hr regard plant personnel suggest personnel chang plant along necessari chang creat corpor environ prior famili own compani feel manag aspect suppli chain develop implement purchas oper logist product system manag vendor supplier contract introduc lean manufactur practic manag bill hr function account manag compani name citi state overal author global intercompani oper organ budget prepar administr audit account monthli close book account reconcili journal entri adjust prepar monthli quarterli annual report summar busi activ develop trend balanc sheet analysi account receiv age report maintain audit report ensur smooth quarterli year end audit supervis lead support staff creat new global polici help streamlin inter compani reconcili process introduc monthli team meet enhanc team environ review project provid train recommend cross train project includ written document process corpor control compani name citi state restructur account depart creat strong team rect report handl sap implement go live challeng
ard effect qualiti control practic develop manag highli effect employe base low rate attrit recogn provid except employe support employ listen first approach navig recess focus like laser beam key compani revenu driver primari cost compani remain cash flow posit quickli mobil septemb meet fast chang market condit appli high level cost analysi compani deploy new procur process secur cog year year reduct survey custom feedback lead industri first includ high speed internet flat screen tv standard item apart cost absorb increas demand servic notabl corpor client l proctor gambl toyota motor manufactur educ ba univers wisconsin green bay citi state gpa gpa gpa languag ...
#
# cv_index=  7
# CV 4 (Similarity Score: 0.962655246257782):
# Category: APPAREL
# File Name: 10562768.pdf
# Resume Text: ['assist bank center manag summari experienc signal analysi geo spatial analysi electron warfar analysi network threat analysi dnr limit knowledg perform dni analysi basic knowledg comput network applic world wide web printer email instant messag knowledg local area network well wide area network expert work knowledg experi googl earth microsoft offic suit variou sigint geospati analyst signal analysi sigdev collect identif analysi process tool applic databas experienc analyt research develop techniqu along manag analysi databas product excel oral written commun skill regular display high level profession problem solv skill bloomberg certifi highli adapt chang environ self starter peopl motiv broad set analyt technic skill profici government health care program regul eg medicar advantag highlight rt rg suit belleview metric anchori globalreach sedb signav nsanet target profil ms offic suit arcmap arcgi googl earth analyst notebook dishfir jwic bloomberg archtic ticketmast marx continuum facet medco med informat care advanc verint cisco citrix experi compani name citi state assist bank center manag current knowledg aspect run retail bank center build oper audit polici procedur gener manag team build comerica secur retail financi product prepar intern instruct oper polici standard oper procedur sop guidelin skill assess fraudul issu plan conduct investig design achiev casualti resolut analyz inspect investig identifi problem area within retail financi program mathemat abil perform calcul includ applic discount interest proport mortgag term percentag profici follow system cisco hogan trio elan mortgag referr tool bloomberg paypoint check vision account analysi aa costar member provid servic compani name citi state member provid servic certifi step ulyss servic mentor program profici follow system macess facet citrix medco careadv health mainten organ continuum marx med informat cisco verint sale custom servic skill use build maintain except relationship subscrib provid small group larg group government program knowledg mdch ncqa mtm nmi experienc follow depart human servic center medicar medicaid servic health insur marketplac compani name citi state box offic associ profici follow system archtic ticketmast michigan lotteri sale abil multi task provid top level salesmanship directli handl custom complaint provid problem solv suffici solut work three locat box offic associ meadowbrook hall dte palac auburn hill compani name citi state head sale associ knowledg aspect run small busi payrol account receiv account payabl gener leadership increas sale understand gener hospit health care practic regul osha skill microsoft offic program experienc medic field sale pitch market strategi mathemat abil perform simpl calcul includ applic discount interest commiss proport percentag compani name citi state sigint analyst assist develop air wave analysi satellit radio conduct pattern analysi identifi known unknown threat develop explor signit target use research develop intellig report product prepar support militari tactic strateg expert work knowledg signit includ comint elint osint well sourc analysi report gain work knowledg report captain squad leader entri level soldier develop improv iir pir analysi collect capabl due injuri unabl complet given contract length compani name citi state aquat associ', 'ymca certif red cross elli lifeguard certif water aerob certif cpr first aid a certif usa certifi swim coach swim instructor certif increas north oakland wave swim team membership lead swim instructor lifeguard monthli cpr a first aid train educ bachelor scienc oakland univers citi state basic train fort leonard wood mo advanc individu train sigint train goodfellow afb tx cochis colleg state master busi administr oakland univers network plu certif expect secur plu certif certif ymca certif red cross elli lifeguard certif water aerob certif cpr first aid a certif usa certifi swim coach swim instructor certif increas north oakland  ...
#
# cv_index=  17
# CV 5 (Similarity Score: 0.9608884453773499):
# Category: BPO
# File Name: 13964744.pdf
# Resume Text: ['team lead senior analyst profession summari mba busi manag financ inform technolog profession summari overal year experi implement support inform technolog oper multipl busi project googl map wipro client hewlett packard year experi project manag oper manag lead multipl small scale larg project staf resourc plan manag metric peopl manag project life cycl manag day day oper kpi project deliv specif time frame determin analyz process requir develop function need process work cross function team year includ train technic qualiti metadata tech stop cross function team like busi analyst qualiti analyst work function lead senior qualiti analyst propos variou solut skill diploma comput applic nicet institut core java complet web design ms offic packag cours aptech comput india jira tool sql microsoft offic powerpoint excel visio project seek pmp certif get certifi earliest work histori team lead senior analyst compani name citi ensur project process adher pre defin standard act liaison senior busi manag variou global stake holder recruit analyst process suggest best practic effect method captur document busi requir transform function strateg manag project initi plan deliv project deliver time frame collabor system specif workflow document new project featur maintain updat exist specif project document capac plan staf resourc alloc per requir possess good written verbal commun skill influenc team member stakehold demonstr variou strateg manag leadership skill execut multipl project oper project lead multipl project cogniz global logic januari april client googl map role respons daili monitor metric investig ineffici improv team process meet kpi monitor work flow conduct qualiti review ensur high standard line project need liais manag regard work flow industri updat chang polici reform analyz requir client need polici transform busi function bridg gap variou cross function team document variou polici process enhanc effect commun track variou metric daili basi gener weekli metric report abil make sound wise decis project solv complex oper problem perform root caus analysi identifi variou problem provid optimum feasibl solut educ coach team member variou polici standard enhanc compet monitor perform analyst ad measur variou perform metric interpret custom feedback monitor satisfact help drive program improv team perform analyz metric recommend oper flow improv base upon analysi experi present variou complex inform data precis understand way drive except custom servic end client experi break problem issu segment resolv strategi given timelin demonstr transpar account variou project throughout leadership career document defin scope time cost project mentor train newbi cross function team variou product function need busi need train associ share knowledg variou process multipl project expert project manag tool like ms share point visio profici excel word powerpoint sql servic escal ticket manag priorit issu relat product resolv amic solut proactiv track bottl neck process resolv provid feasibl solut write sql queri updat check dashboard metric ensur oper effici enhanc kpi abil work independ minim supervis work variou differ cross function team like busi qualiti analyst other associ analyst design develop variou busi work project part integr understand exist framework applic', 'determin requir translat busi requir provid solut complex challeng variou cross function team highlight issu pertain process document best practic process enhanc profici use excel sql basic queri data extract analyz report associ analyst compani name help custom give feasibl solut relat window oper system solv complex problem pertain comput hardwar softwar troubleshoot internet network cabl issu comput peripher suggest altern product pitch sale achiev csat kpi provid optimum solut custom satisfact resolv custom queri pertain h p product achiev custom satisfact data entri specialist analyst kelli servic client googl analyz data use variou queri transform ...
#
# Job Description 2:
#  Appledescription
# as an asc you will be highly influential in growing mind and market share of apple products while building longterm relationships with those who share your passion
# customer experiences are driven through you and your partner team growing in an ever changing and challenging environment you strive for perfection whether its maintaining visual merchandising or helping to grow and develop your partner team
#
# qualifications
# a passion to help people understand how apple products can enrich their livesexcellent communication skills allowing you to be as comfortable in front of a small group as you are speaking with individuals years preferred working in a dynamic sales andor results driven environment as well as proven success developing customer loyaltyability to encourage a partner team and grow apple business
#
# Top 5 CVs:
# cv_index=  26
# CV 1 (Similarity Score: 0.890099048614502):
# Category: DESIGNER
# File Name: 10466583.pdf
# Resume Text: ['floral design summari person custom servic associ dedic provid highest level custom servic outgo effici capac multi task highlight inventori control employe schedul cash handl bank floral design organ place order person phone custom servic excel multi tasker experi june march compani name citi state floral design design arrang wide rang event includ wed corpor parti prep work well kept showroom clean maintain properli display januari decemb compani name citi state floral design open close store includ count cash drawer make bank deposit help custom select product best fit person need well floral design april august compani name citi state cashier cashier main function addit help unload truck stock shelv carri merchandis floor custom mark clearanc product updat price tag octob april compani name citi state manag floral design open close store includ count cash drawer make bank deposit maintain visual appeal effect display entir store answer custom question address problem complaint person via phone help custom select product best fit person need well design floral arrang cooler display outgo order educ northwestern colleg citi state dupag medic assist']
#
# cv_index=  32
# CV 2 (Similarity Score: 0.8853824138641357):
# Category: FINANCE
# File Name: 10549585.pdf
# Resume Text: ['financ manag oper manag career overview obtain full time posit manag inform system emphasi busi analysi demonstr excel leadership busi team work skill produc effect result qualif technic help desk experi strong analyt skill strong collabor skill document manag excel problem solv skill strong commun skill custom need assess requir analysi requir gather c java cic window network w lan technic support switch bridg softwar develop life cycl system applic system develop system implement system integr pc do person comput problem analysi resolut process improv product life cycl manag product manag product research project qualiti control qa qualiti product improv technic skill skill experi total year last use accomplish train success train employe use new oper system network secur plan instal maintain optim document lan wan vpn network hardwar softwar secur system commun link manag client network lan wan hardwar includ router switch load balanc wireless network equip network support act first point contact major technic issu includ power outag system failur disast recoveri oversaw infrastructur three offic act support help desk technician depart work experi financ manag oper manag juli current compani name citi state overse aspect organ qualiti busi improv effort develop administr program train coach employe facilit chang throughout organ respons establish strateg plan polici procedur level qualiti improv effort meet exceed intern extern custom need expect implement new sale track po system replac manual form write process increas effici provid employe train po system recruit hire train develop direct retail sale team two retail wireless nation dealer store oversaw client relat new account develop custom servic supervis administr function inventori cash flow merchandis oper gener monthli annual sale report', 'conduct ongo staff develop person growth plan employe doubl annual sale develop innov effect market program creat team spirit within store result increas sale long term employe custom satisfact achiev quota grew number custom within first year sale manag led sale call team member establish sale custom retent goal determin merchandis price schedul discount rate monitor custom prefer determin focu sale effort share product knowledg custom make person recommend maintain friendli profession custom interact negoti close contract fortun compani includ sprint wireless mobil comput inform system specialist ii septemb juli compani name citi state administ instal configur continu mainten network equip includ server storag devic router hub switch printer troubleshoot resolv network connect network relat hardwar softwar problem process averag inbound outbound technic support call review new hardwar softwar specif recommend product procur instal configur optim network commun hardwar client softwar refer difficult issu upper manag maintain posit rapport custom creat user assign privileg provid ongo user support research issu variou comput system databas resolv complaint answer inquiri respond connect relat help desk request maintain composur patienc face difficult custom situat run backup recoveri oper provid support assist staff resolv custom complaint concern strong verbal negoti skill display courtesi strong interperson skill custom interact complet archiv network data complet appropri document collabor teacher coordin assess evalu educ softwar project futur need built maintain success relationship servic provid dealer consum educ train masterof scienc inform system bowi state univers citi state gpa bachelor scienc inform system univers maryland univers colleg citi state coursework softwar engin hardwar system coursework distribut comput network databas skill administr backup cash flow coach hardwar client client relat custom satisfact custom servic document help desk hub inventori market merchandis network polici po printer procur qualiti qualiti improv retail retail sale router sale server staff develop strateg plan switch ...
#
# cv_index=  47
# CV 3 (Similarity Score: 0.8817048072814941):
# Category: TEACHER
# File Name: 10527994.pdf
#
# cv_index=  18
# CV 2 (Similarity Score: 0.9627039432525635):
# Category: BUSINESS-DEVELOPMENT
# File Name: 10228751.pdf
# ...
#
# cv_index=  16
# CV 2 (Similarity Score: 0.9642715454101562):
# Category: BPO
# File Name: 11183737.pdf
# Resume Text: ['manag administr facil execut summari motiv administr profession seek posit challeng environ year experi success provid administr secretari support oper depart profici rang comput applic well develop commun custom servic skill proven abil effici plan manag multipl assign meet tight deadlin proactiv problem solver get job done core qualif compens benefit administr chang manag inventori control staff develop oper manag polici program develop skill negoti supervis train comput savvi travel administr schedul manag self starter deadlin orient spreadsheet develop profession experi manag administr facil januari januari compani name citi respons manag travel transport relat offici activ maintain healthi work environ disciplin handl variou compani vehicl coordin air travel hotel book arrang confer hall book also travel arrang visa offici purpos per requir account board lodg manag head guest liais vendor purchas order vendor reconcili invoic agreement ensur time payment sap knowledg effici inventori manag vendor manag liais variou author depart smooth commerci oper shipment good materi outlet maintain updat premis leas agreement liaison variou govern agenc like electr offic municip offic telecom offic etc handl overse alloc workplac telecommun infrastructur regular necess employe facil respons maintain hygien surround effici manag variou branch oper activ coordin housekeep secur manag servic activ depart assur staff follow establish safeti regul use equip suppli time maintain control uniform need department staff requisit suppli equip maintain adequ inventori level provid clean safe comfort environ keep mainten equip machin schedul clean shift wise maintain visual appear aesthet cor premis problem resolut job safeti practic etc ensur staff properli train tool equip need effect carri respect job duti complet event manag meet confer intern event organ account util mainten offic furnitur includ procur offic furnitur equip variou outsourc servic like secur servic printer stationeri supplier electrician water supplier travel agent etc assist manag januari januari compani name citi independ handl overal function manag food beverag outlet implement strict measur custom care procedur optim guest satisfact retent ensur specif control mainten best practic servic hygien liais chef menu plan menu select season festiv base custom review respons servic satisfact varieti guest divers background success mainten intern standard utmost commit work handl guest relationship plan execut oper ensur qualiti servic manag guest request complaint feedback display cordial attitud toward referr repeat busi enhanc profit achiev high guest satisfact indic score maintain detail administr procedur process improv accuraci effici success establish effect system record retent creat databas daili correspond track train administr manag januari januari compani name citi analyz depart train need develop new train program base analysi design train modul implement strateg busi practic organiz behavior train concept design develop train develop', 'program base organ individu need consid cost plan program kept within budget work team produc program satisfactori relev parti organ line manag account senior manag board level devis individu learn plan produc train materi hous cours assist manag deliveri train develop program ensur statutori train requir met evalu train develop program help line manag trainer solv specif train problem one one basi group develop use altern learn method practic coach e learn clinic supervisor shadow support workforc develop benchmark independ handl overal function manag food beverag outlet implement strict measur custom care procedur optim guest satisfact retent ensur specif control mainten best practic servic hygien liais chef menu plan menu select season festiv base custom review respons servic satisfact varieti guest divers background success mainten intern standard utmost commit work handl guest relationship plan execut oper ensur qua ...
#
# cv_index=  40
# CV 3 (Similarity Score: 0.9639160633087158):
# Category: INFORMATION-TECHNOLOGY
# File Name: 10089434.pdf
# Resume Text: ['inform technolog technician summari versatil system administr possess superior troubleshoot skill network issu end user problem network secur experienc server manag system analysi offer depth understand infrastructur area detail orient independ focus take systemat approach solv complex problem demonstr except technic knowledg skill work variou team achiev share goal object highlight activ directori group polici object powershel vbscript microsoft exchang vmware experi new technolog product research offic azur storag manag enterpris backup manag disast recoveri experi inform technolog technician aug current compani name citi state migrat manag user account microsoft offic exchang onlin creat manag virtual machin system domain control activ directori feder servic adf microsoft window azur iaa creat manag storag microsoft window azur iaa instal configur storsimpl iscsi cloud array staa baa instal configur test twinstrata iscsi cloud array staa baa collabor project plan offic migrat develop detail specif offic migrat includ busi case document cost benefit analys technic diagram work flow document receiv train mvc visual studio use net framework develop applic use html css instal configur support linux machin open wi fi network project compil gener statist inform concern wireless network traffic use cacti configur wireless lan router network secur access instal configur wireless certif develop detail specif acquisit enterpris backup system includ system design busi case document cost benefit analysi technic diagram work flow document review evalu analyz department polici guidelin procedur standard manag staff develop test script accept unit system test hyperion phase miamibiz phase develop qualiti assur test plan hyperion phase miamibiz phase debug log error hyperion miamibiz use team foundat server tf particip variou phase project life cycl determin requir design conceptu test implement deploy releas hyperion miamibiz project collabor project plan hyperion miamibiz prepar present document demonstr hyperion miamibiz function design monitor network traffic compil gener statist inform use solar wind collabor disast recoveri plan procedur research evalu recommend new hardwar new softwar commun defin system design requir new exist system applic research evalu recommend test implement third parti softwar util plan design network infrastructur chang ad remov server applianc network logic flow review evalu analyz exist system applic viabil manag staff administ maintain share file server review server log troubleshoot issu schedul appli hot fix secur patch server infrastructur includ oper system applic softwar review system report sccm system center configur manag resolv servic request escal help desk technician troubleshoot analyz system problem root caus analysi give particip train educ program explain upgrad end user migrat user document local comput storag share file server configur support maintain file share use distribut file system df manag implement test enterpris backup infrastructur system symantec verita netbackup symantec backup exec system recoveri livest vranger backup server manag configur support datadomain storag configur support microsoft window server instal configur support microsoft window window microsoft offic', 'instal configur support mcafe anti viru softwar server migrat exchang infrastructur exchang exchang exchang exchang support server virtual infrastructur use vmware vsphere instal configur test veeam virtual machin backup softwar virtual desktop infrastructur vdi review system report system center configur manag sccm administ maintain symantec enterpris vault server manag activ directori domain control dc creat maintain group polici object gpo microsoft activ directori configur support microsoft exchang activ sync devic appl io android mobil oper system configur support blackberri devic blackberri enterpris server receiv exchang email develop test design implement applic script use languag com ...
#
# cv_index=  3
# CV 4 (Similarity Score: 0.963509202003479):
# Category: ADVOCATE
# File Name: 10344379.pdf
# Resume Text: ['summari administr support profession experi work fast past environ demand strong organiz technic interperson skill trustworthi ethic discreet commit superior leadership custom servic technic support work individu team environ confid pois interact individu level detail orient resourc complet project time abl multi task effect capabl includ logist distribut manag medic devic repair technician product oper supervisor ship receiv supervisor custom servic repres excel written verbal commun experi custom servic advoc jan current compani name citi state respons answer incom call custom ensur high level custom servic maxim product direct phone base custom interact answer resolv wide varieti inquiri includ limit pharmaci benefit mail order pharmaci assist call assist custom pharmaci physician order reorder benefit elig question prescript inquiri escal drug relat call appropri pharmacist assist pharmaci member issu relat process pharmaci claim determin appropri overrid pharmaci claim edit error messag coordin intern resolut claim except issu assist enter new prescript order system educ custom benefit use plan formulari premium statu order claim inquiri medic devic repair technician feb may compani name citi state inspect test malfunct medic relat equip follow manufactur specif use test analysi instrument test calibr compon equip follow manufactur manual troubleshoot techniqu use hand tool power tool measur devic perform prevent mainten servic clean lubric adjust equip examin medic equip facil structur environ check proper use equip protect patient staff electr mechan hazard ensur complianc safeti regul research catalog repair part list locat sourc repair part requisit part record receipt solder loos connect use solder iron field electron technician jan jan compani name citi state read interpret schemat draw diagram blueprint specif work order report determin materi requir assembl instruct assembl electr electron system support structur instal compon unit subassembl wire assembl case use rivet blot hand tool power tool measur devic explain assembl procedur techniqu worker confer supervisor engin plan review work activ resolv product problem product team lead jan jan compani name citi state achiev work standard follow product product qualiti custom servic standard resolv oper problem identifi work process improv accomplish work requir orient train assign schedul coach employe confer supervisor coordin oper activ within depart enhanc depart organ reput accept ownership accomplish new differ request explor opportun add valu job accomplish custom servic repres jan jan compani name citi state handl custom question complaint bill inquiri highest degre courtesi profession resolv custom issu one call resolut commun custom use web base tool demonstr profici type grammar made financi decis protect collect revenu adjust custom account assist call center manag assist custom servic repres handl escal difficult custom concern educ logist suppli chain manag post secondari train certif florida state colleg jacksonvil citi state diploma concord career institut citi state militari servic unit state armi commun specialist receiv honor discharg skill']
#
# cv_index=  18
# CV 5 (Similarity Score: 0.9619296789169312):
# Category: BUSINESS-DEVELOPMENT
# File Name: 10228751.pdf
# Resume Text: ['busi develop manag staf manag profession summari innov manag seek posit offer opportun new profession person challeng self starter posit attitud driven learn improv succeed year proactiv indirect divers recruit staf experi educ train bachelor scienc health scienc option health manag market california state univers hayward citi state unit state skill highlight staf manag abil proven patienc self disciplin relationship team build staff train develop critic think profici compens benefit administr skill negoti account manag excel written verbal commun enthusiast team player problem solv bill attent detail recruit select techniqu profici commun contract review cold call hire recommend interview strateg plan multi task abil skill profici microsoft word excel powerpoint access outlook express optim wfx stafferlink healthtrust bullhorn maintain activ databas variou hospit proprietari softwar technolog system profession experi current busi develop manag staf manag compani name citi state manag full cycl staf recruit maintain databas client applic align busi opportun market recruit staf placement respons job post hire interview train new employe gener new account implement effect network content market strategi manag budget forecast goal set perform report account negoti rate cut cost benefit corpor partnership demonstr knowledg hipaa privaci secur regul conduct refer background check job applic develop creativ recruit strategi met anticip staf need commun duti compens benefit work condit potenti candid contact job applic inform applic statu work director nurs human resourc director ensur healthcar organ abl support busi growth coach counsel employe regard attend perform mediat employe disput complaint respond onboard new employe time report payrol system manag payrol time attend system staf coordin compani name citi state creat maintain absente calendar agenc nurs schedul staff meet minut maintain confidenti personnel file licens cpr complianc record develop computer schedul assign nurs unit base establish staf pattern polici approv employe prefer manag request revis adjust unit schedul need consult nurs manag proactiv adjust alloc core registri float nurs personnel provid adequ coverag clinic inpati area strateg meet real time staf requir cost effect manner staf manag compani name citi state manag full cycl staf recruit maintain databas client applic align busi opportun market recruit staf placement respons job post hire interview train new employe gener new account implement effect network content market strategi manag budget forecast goal set perform report account negoti rate cut cost benefit corpor partnership demonstr knowledg hipaa privaci secur regul conduct refer background check job applic develop creativ recruit strategi met anticip staf need commun duti compens benefit work condit potenti candid contact job applic inform applic statu work director nurs human resourc director ensur healthcar organ abl support busi growth coach counsel employe regard attend perform mediat employe disput complaint respond onboard new employe time report payrol system manag payrol time attend system']
