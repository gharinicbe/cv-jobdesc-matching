# %%
import PyPDF2
import pandas as pd
import numpy as np

from textblob import TextBlob
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import os
import re
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

dataset_root_folder = './Resumespdf/data/data'
dataset = pd.read_csv('./jobdesc_data.csv')

def text_cleaning(text):
    
    # Remove HTML tags 
    cleaned_text = re.sub(r'<.*?>', ' ', text)
    
    # Remove non-english characters, punctuation,special characters, digits, continous underscores and extra whitespace
    cleaned_text = re.sub('[^a-zA-Z]', ' ', cleaned_text)
    cleaned_text = re.sub(r'[^\w\s]|_', ' ', cleaned_text)
    cleaned_text = re.sub(r'\d+', ' ', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    cleaned_text=re.sub('http\S+\s', " ", cleaned_text)
    
    
    
    # Convert to lowercase
    cleaned_text = cleaned_text.lower()
    
    # Tokenize the cleaned text
    words = word_tokenize(cleaned_text)
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    
    # Tokenize the cleaned text
    words = word_tokenize(cleaned_text)
    
    # Apply stemming
    stemmer = PorterStemmer()
    stemmed_words = [stemmer.stem(word) for word in filtered_words]
    
    cleaned_text = ' '.join(stemmed_words)
    
    return cleaned_text

def extract_specific_lines(pdf_file_path):
    sents = []
    with open(pdf_file_path, "rb") as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        for page in pdf_reader.pages:
                       
            text = page.extract_text()
            # Clean extracted text
            cleaned_value = text_cleaning(text)
            # Use TextBlob to split sentences
            blob = TextBlob(cleaned_value)
            sents.extend(blob.sentences)
            
    # Define keywords to search for
    keyword_lines = []
    
    # Iterate through lines and check for keywords
    for sent in sents:
        sent = str(sent)  # Convert TextBlob line to a string
        #print ('sent: ', sent)
        words = TextBlob(sent.lower()).words 
        
        if "educ" not in words and "skill" not in words:
            continue
        
        keyword_lines.append(sent)
        
        #print(keyword_lines)
     
    return keyword_lines

data = []
resumes_list =[]
for category_folder in os.listdir(dataset_root_folder):
    #count = 0
    category_folder_path = os.path.join(dataset_root_folder, category_folder)
    if os.path.isdir(category_folder_path):
        for filename in os.listdir(category_folder_path):
            if filename.endswith(".pdf"):
                pdf_path = os.path.join(category_folder_path, filename)
                #for every resume extract only the specific lines with keywords
                resume_lines = extract_specific_lines(pdf_path)
                if len(resume_lines) <=0:
                    continue
                #append the resume_lines as strings in reasumes_list
                resumes_list.append(resume_lines[0])                                
                category = category_folder
                filename = filename 
                #append category_folder, filename, resume_lines for creating a pandas dataframe
                data.append([category_folder, filename, resume_lines])
#                 count += 1
#                 if count == 2:
#                     break
# Create a Pandas DataFrame using the data list
df1 = pd.DataFrame(data, columns=["Category", "File", "Line"])

# Select the first 10 job descriptions and company names
job_descriptions = dataset["job_description"][:10]
companies = dataset["company_name"][:10]

# Create a new DataFrame and set the index
df = pd.DataFrame({'Job Description': job_descriptions})
df.index = companies
#print(df.head())
#Covert Job Description in the dataframe to list of strings and clean
job_description = list(df['Job Description'])
job_description_cleaned = []
for job in job_description:
    job_description_cleaned.append(text_cleaning(job))
#print(job_description_cleaned)


#load model

model  = SentenceTransformer("bert-base-uncased")

# embedding of list

embeddings =  model.encode(resumes_list)
embeddingsSearched = model.encode(job_description_cleaned)

#finding similarity
similarity = cosine_similarity(embeddingsSearched, embeddings)

# Iterate through job descriptions
for i, job_description in enumerate(job_description_cleaned):
    print(f"Job Description {i + 1}:\n {df.index[i]}:\n{df['Job Description'][i]}\n")
    
    # Get similarity scores for this job description
    similarity_scores = similarity[i]
    
    # Sort CVs by similarity score (highest to lowest)
    sorted_indices = similarity_scores.argsort()[::-1]
    
    # List the top 5 CVs for this job description
    top_cv_indices = sorted_indices[:5]
    
    print("Top 5 CVs:")
    for j, cv_index in enumerate(top_cv_indices, start=1):
        print("cv_index= ",cv_index)
        print(f"CV {j} (Similarity Score: {similarity_scores[cv_index]}):")
        print(f"Category: {df1['Category'][cv_index]}")
        print(f"File Name: {df1['File'][cv_index]}")
        print(f"Resume Text: {df1['Line'][cv_index]}\n")


# Now, resumes listed are top 5 resumes (as text) for each job description,
# and the code prints them alongside the job descriptions.
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Harini
# [nltk_data]     Balaji\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Harini
# [nltk_data]     Balaji\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# No sentence-transformers model found with name C:\Users\Harini Balaji/.cache\torch\sentence_transformers\bert-base-uncased. Creating a new one with MEAN pooling.
# Job Description 1:
#  Google:
# minimum qualifications
# bachelors degree or equivalent practical experience years of experience in saas or productivity tools businessexperience managing enterprise accounts with sales cycles
# preferred qualifications
#  years of experience building strategic business partnerships with enterprise customersability to work through and with a reseller ecosystem to scale the businessability to plan pitch and execute a territory business strategyability to build relationships and to deliver results in a crossfunctionalmatrixed environmentability to identify crosspromoting and uppromoting opportunities within the existing account baseexcellent account management writtenverbal communication strategic and analyticalthinking skills
# about the job
# as a member of the google cloud team you inspire leading companies schools and government agencies to work smarter with google tools like google workspace search and chrome you advocate the innovative power of our products to make organizations more productive collaborative and mobile your guiding light is doing whats right for the customer you will meet customers exactly where they are at and provide them the best solutions for innovation using your passion for google products you help spread the magic of google to organizations around the world
# the google workspace team helps customers transform and evolve their business through the use of googles productivity collaboration and content management suite of applications as part of an entrepreneurial team in this growing business you will help shape the future of businesses use technology to connect with customers employees and partners
# as a google workspace sales specialist you will be responsible for maintenance and expansion of google workspace business growth across the region with customers in this role youll create and execute the strategy and provide unique insights on applying google workspace solutions to enterprisesyou will build an excellent pipeline and work with the account teams to build out the customer solution and establish partnerships you will strategize with partners to increase account and territory business growth you will work directly with customers coordinate internal resources and construct successful strategies at account and territory level
# google cloud accelerates organizations ability to digitally transform their business with the best infrastructure platform industry solutions and expertise we deliver enterprisegrade solutions that leverage googles cuttingedge technology  all on the cleanest cloud in the industry customers in more than  countries and territories turn to google cloud as their trusted partner to enable growth and solve their most critical business problems
#
# Top 5 CVs:
# cv_index=  239
# CV 1 (Similarity Score: 0.9749173521995544):
# Category: AGRICULTURE
# File Name: 11813872.pdf
# Resume Text: ['vp princip summari highli skill growth mindset profession year experi mostli financi industri relat provid advanc data solut use innov databas technolog innov creativ great problem solver achiev highest rate consist year continu learn adapt evolv overcom challeng face profession career fortun part team deliv cut edg product year help firm client career philosophi lt listen learn love lead earn trust skill deep expertis design develop implement run mission critic system involv oltp olap htap workload extens experi build deploy larg scale applic cloud environ aw deep expertis advanc data model data manag data govern passion leader build lead strong team build deliv support world class product ibor use innov technolog hand develop busi manag princip solut architect deep expertis front offic middl offic back offic relat busi workflow financi industri deep expertis financi instrument model includ complex deriv product portfolio invest manag deep expertis oracl exadata amazon redshift sql python java apach ignit aw relat technolog basic experi data scienc relat technolog e g panda matplotlib etc agil develop methodolog e g jira quick leaner abil solv complex busi problem activ member multipl work group establish data strategi data govern data qualiti enterpris data architectur e g busi architectur data architectur data qualiti work group financi instrument valuat exposur experi thought leader key note speaker memori comput summit experi current vp princip compani name citi state architect develop innov product call ibor provid real time market valu exposur relat analyt use oper data store od product capabl show look exposur complex instrument e g pool fund etf exot deriv product e g total return swap index futur game chang product use broadli wellington investor client sinc design develop data qualiti reconcili process detect respond prevent data qualiti issu product environ mission critic product deliv mani qualiti product product well time budget limit number resourc proactiv took ownership resolv complex problem face team result achiev highest rate ever possibl manag year row built strong resili team team member support huge demand product develop team respons develop deliv support multipl mission critic applic product posit team well innov new qualiti product well support exist product product led team design develop product provid invest perform return across financi instrument use innov memori design product also provid uniqu capabl provid look perform complex financi instrument wellington new product improv system perform huge margin legaci product run success product sinc led team success build deliv transact process system known unifi transact system repres transact unifi format provid roll posit exposur perform data meet emerg busi requir due continu success huge demand product built team team ask build next gener ibor platform ibor singl sourc truth invest hold inform provid consist time accur posit exposur inform help front offic make invest decis ibor provid current histor oper invest data use mani financi firm middl offic front offic ibor perfect use case combin oper analyt workload aka hybrid transact analyt process htap ibor product sinc sep aw cloud environ use gridgain ignit memori comput platform team work build ibor use proprietari technolog databas use htap architectur princip architect ibor design data model instrument transact meta model key foundat compon build highli avail reliabl optim ibor architectur ibor transact base system provid real time posit exposur invest perform data use one unifi platform ibor provid current histor data light speed due innov cut edg technolog ibor foundat data platform enabl tier applic migrat monolith architectur servic base architectur design develop implement support oper histor data store od applic tb use oracl exadata od maintain histor posit exposur perform data team also migrat data built data pipelin oracl', 'amazon redshift provid faster perform olap time ...
#
# cv_index=  1174
# CV 2 (Similarity Score: 0.9731912016868591):
# Category: CONSULTANT
# File Name: 20314980.pdf
# Resume Text: ['simul variabl amount supermarket simultan hit oracl databas face short deadlin provid train custom thailand develop five day cours includ hand demo use vmware workstat result success knowledg transfer led technic team provid pre sale support system analysi plan implement park citi group product multipl new custom result success execut undertook role system administr compani top duti departur employe quickli gain understand variou complex system document spent time hour studi system previous experi abl provid support exxonmobil senior system technic analyst sep sep citi state respons technic applic deliveri infrastructur desktop worldwid provid level technic support engin geoscientist around world suppli task driven script user support engin data manag staff work end user identifi applic requir creat deploy solut manag differ team largest project exxonmobil repackag applic msi format roll xp desktop develop program autom sm deploy result annual save increas custom satisfact due faster applic deliveri manag conflict resolut team reduc manpow team strict process best practic design save contractor cost xp rollout project led team employe applic deploy team implement recycl coordin queue perform root caus analysi cut costli applic failur product matter month result save learn activ directori week subsequ train peopl use repackag applic year assign difficult app quickli complet train new employe becam solid perform built applic stewardship team ground util contractor employe document develop process best practic team exceed initi goal complet app everi day complet applic per day promot new level year leverag exist program skill learn perl produc sm script assist supervisor recov licens cost personnel transfer occur save thousand dollar unus licens educ bs busi mi brigham young univers citi state busi mi skill vb net asp net activ directori ad machin streamlin ad applic packag autom backup hardwar conflict resolut consult consult encrypt client custom satisfact data manag deliveri desktop direct xml financi ii imag imag installshield inventori itil knowledg manag leadership manag market access c exchang window os window window window win window k work migrat msi enterpris network os oracl databas packag perl personnel process program project manag report sale support script script sm spanish ms sql server system analysi technic support user support tech support uniqu vbscript view vpn websit x']
#
# cv_index=  1449
# CV 3 (Similarity Score: 0.9717459678649902):
# Category: DIGITAL-MEDIA
# File Name: 80679862.pdf
# Resume Text: ['digit market specialist highlight strong digit market experi use social media platform profici follow program tool applic slack googl analyt adword site catalyst omnitur adob analyt microsoft excel word appl page number adob creativ photoshop lightroom illustr final cut pro avid mail chimp constant contact work zone mind jet salesforc gitlab github cv wordpress dreamweav experi compani name januari current digit market specialist citi state strateg manag use expertis interpret e commerc merchant object data insight digit market requir digit plan push think custom merchant project integr search market broader digit market channel perform advanc acquisit lead gener initi appli analyt technic skill problem solv iter campaign observ follow e commerc technolog trend resourc emerg marketplac analyz interpret raw data point uncov new busi opportun interpret chart spreadsheet present creat market opportun identifi need opportun develop action plan address abl think strateg tactic develop appropri project plan timelin coordin negoti project plan team member depart ensur project complet accuraci frequent updat senior manag project progress digit oper identifi process improv across plan account manag goal optim busi oper work independ minimum supervis demonstr digit expertis guid user best practic teach leverag system function effort introduc busi effici design content architectur layout facilit respons site ensur site optim cross platform cross browser compat custom feedback experi subject matter expert sme possess strong organiz time manag skill drive task complet develop demand gener strategi manag market program drive demand cross border product digit agil excel collabor environ come idea contribut convers quick think solut build solid effect work relationship other facilit particip group interact ad brainstorm build idea relat individu nurtur talent central effect work togeth construct work stress pressur face high workload deadlin abl adjust readili chang adapt need abil express idea clearli convey necessari inform interact effect level manag maintain posit attitud face critic reject failur servic market intellig expert cross border audienc competit sens humor help make collabor fun provid subject matter expertis usabl fedex com style guid adher across websit web applic email market autom code manag email market market autom program includ set schedul test tag deploy one time recur trigger campaign troubleshoot technic issu relat integr templat list segment lead score grade aspect market autom execut requir recogn attend import detail accuraci effici tool program bronto softwar dreamweav sublim text search engin market perform keyword research use page search engin optim seo research analyz competitor develop implement link build strategi collabor develop team ensur ppc seo best practic follow perform analysi seo strategi site keyword convers perform traffic target goal improv convers rate tool program adob analyt omnitur site catalyst googl analyt observepoint new relic googl adword digit pr identifi opportun digit market pr effort highlight editori product brand stori creat content market initi strateg allianc merchant global effort great network skill confid coordin key busi stakehold go market sale creat collater sale forc go market messag posit competit differenti develop sale tool support sell process plan launch new product releas product version updat manag cross function implement plan across team analysi insight conduct report detail analys understand perform market user experi content evalu campaign progress bottom line impact roi custom insight lead optim recommend iter improv monitor speed applic increas digit user experi dux tool profession practic observepoint b', 'test usertest com new relic manag websit updat site skeleton along maintain brand continu throughout digit web page analyt tool custom interact adob analyt omnitur site catalyst dreamweav html parallel tortois new relic adob experi manag aem ...
#
# cv_index=  2123
# CV 4 (Similarity Score: 0.9707525968551636):
# Category: INFORMATION-TECHNOLOGY
# File Name: 33381211.pdf
# Resume Text: ['vice presid inform technolog softwar engin profession summari result driven busi mind technolog leader year experi technolog softwar develop profession passion develop peopl team reach greatest potenti thought leader partner busi drive strategi concept execut team player place prioriti network relationship build divers achiev greatest possibl outcom progress technolog leader innov growth mindset skill peopl center leadership strateg tactic plan softwar engin design architect system coach talent develop build cultur innov engag transform chang advoc work histori vice presid inform technolog softwar engin current compani name citi state lead aspect applic develop corpor system team encompass associ plu consult budget key capit tran form project full life cycl deliv world class busi solut support compani wide fit growth initi focus improv custom associ experi transform busi process leverag modern technolog solut replac antiqu system lead technolog transform focus platform legaci core system cloud microservic contain base architectur run aw platform allow safelit deliv busi valu faster improv speed market lead implement robot process autom rpa autom manual repetit busi process anticip save per year assist vice presid solut deliveri compani name citi state defin execut product vision safelit overal core system architectur drive busi growth nation contact center retail locat mobil technician warehous distribut center multipl custom driven respons web applic custom app engag tool drove adopt agil methodolog across technolog team busi unit built high perform autonom agil product team highli engag safelit busi team deliv product valu custom extend safelit core system enabl overal omni channel vision safelit abl seamlessli servic custom central unifi platform provid consist servic regardless custom channel choic manag success deliveri custom engag initi watch us way app servic email way text text chat web chat multi modal self servic experi chat bot pilot ivr via aw connect person promo code email campaign leverag sale forc market cloud etc launch road innov program engag motiv team member promot innov lead chang adopt emerg technolog renov system improv custom experi led architectur deliveri first ever cloud base end end claim solut support type claim nation contact center sunset legaci move custom case manag tool sale forc servic cloud sale data bi platform oversaw implement new enterpris integr platform mulesoft director technolog compani name citi state manag success deliveri web respons self servic digit portal policyhold agent insur claim adjust cash custom led legaci safelit com site upgrad modern web respons self servic site onlin convers self servic usag went year manag design implement new servic layer rest api enabl echo system insur carrier integr led implement end end ivr solut key insur partner api integr insur partner websit glass schedul oversaw implement new inventori manag forecast system oracl eb gain inform technolog manag compani name citi state transform safelit system team safelit solut safelit autoglass servic autoglass busi unit legaci platform run support team modern system smaller product team capabl extend need busi function support safelit growth', 'manag effort platform legaci point sale price schedul work order manag inventori system lead technic effort move distribut servic architectur use net build applic wcf servic manag implement new glass claim manag system migrat insur carrier glass claim process legaci mainfram system lead design architectur move distribut architectur use net c sql server team lead compani name citi state inform technolog consult compani name citi state educ mini mba boston univers bs electron commun engin anjuman engin colleg citi www linkedin com boppanarao affili stevi award gold winner watch us way app safelit solut innov award new claim manag tool belron except custom servic award part identif safelit group custom driven leadership award belron except servic awar ...
#
# cv_index=  2081
# CV 5 (Similarity Score: 0.9705711603164673):
# Category: INFORMATION-TECHNOLOGY
# File Name: 20879311.pdf
# Resume Text: ['director inform technolog analyt summari accomplish senior manag year experi lead complex project manag resourc optim enterpris technolog support busi object commit qualiti servic excel aptitud launch new technolog platform subject matter expert inform secur risk manag excel commun adept identifi busi need bridg gap function group technolog foster target innov solut highlight os platform microsoft window server exchang ii activ directori dn network cisco lan wan asa switch tcp ip vpn voip sip mpl vnc vlan segreg hardwar san fiber technolog enterpris server switch router workstat laptop mobil devic
#
# cv_index=  471
# CV 2 (Similarity Score: 0.9715638160705566):
# Category: ARTS
# File Name: 36758947.pdf
# Resume Text: ['account servic repres ii tech summari profession account manag train build strateg network tie increas salesrevenu cultiv maintain strong custom relationship accomplish prospect cold callingexcel communicatorstrong interperson skillscustom servic focusedteam build expertisetech savvyskil ms officeproject managementproven sale track recordpromot campaignspowerpoint expertleadership commun skillsskil multi taskerstrong organiz skillsstrong communicatoract listen skillsexcept custom servic skillsself motiv accomplish name employe month c spire winner c spire employe quarter award st quarter maintain survey rate entir tenur foshe residenti top new account foshe residenti st place southeast region american kickbox academi tournament x shogunmma experi account servic repres ii tech januari may compani name state project design develop leadmay henderson thoma birmingham alabama discov design build new user experi drive next gener portal applic web properti includ mobil design visual stun cut edgegraph anim interact web site portal applic produc visualasset need develop team contribut build compani brand portal applic mobil app web site execut user interfac design consist alldeliver refin low high fidel wirefram design informationarchitectur navig model process flow page layout inform display andinteract compon base user research partnership user experienceinteract design research commun trend best practic relat visualdesign brand everi team member c spire crew charg bring strateg vision ofperson wireless life respons achiev sale goal custom satisfactionstandard design retail locat asr must demonstr strong aptitud andknowledg thing technolog person custom need project anenerget upbeat profession imag posit also respons integratingtechnolog consum life amaz eas effect asr ii alsocharg extra supervisori duti key hold employe manag andinventori audit develop maintain store promot coordin withappropri personnel implement manag wireless sale event provid posit reinforc adult learn techniqu promot learn skill improv particip fiber home instal receiv basic knowledg telephon cabl internet home instal success increas posit smile theworkplac promot group activ continu met quota pass customerexperi survey mysteri shop gain promot level ii key holder assistantmanag posit base experi perform januari decemb compani name citi state respons supervis assist staff ensur well inform positionrespons perform expect manag leas staff arerespons agent overal perform includ leas number enter traffictrain new staff well provid go train feedback perform ensuresthat build offic properli staf time approv time request staffensur staff provid necessari custom relat superior custom satisfactionroutin inspect properti ensur safe determin repair ormainten need monitor properti vendor ensur qualiti servic process workord monitor direct properti mainten oper ensur complianc withcompani standard respond tenant request issu time manner maintaincustom servic standard resid relat complet leas administrativepaperwork account market survey keep leas occup rent highestdesir level review delinqu assist collect may overse prepar ofbudget financi statement period report statu variou properti leaseexpir relat matter ensur marketreadi condit vacant unit managesturn coordin leas termin preliminari inspect apart turn overprovid tour apart commun potenti resid purpos leasingapart coordin outreach market advertis conduct leas process withprospect absenc leas consult complet project request directedbi supervison martial art instructor client januari may compani name state instruct student vari martial art techniqu prepar distribut detail monthli quarterli yearli report client provid requir inform document toclient prepar report client meet record detail futur refer', 'submitcli meet report manag supervisor provid support assist tomanag team audit client liaison activ account revis submiss accountsclosur applic develop liaison client servic collect depart providerequir inf ...
#
# cv_index=  1449
# CV 3 (Similarity Score: 0.9703219532966614):
# Category: DIGITAL-MEDIA
# File Name: 80679862.pdf
# Resume Text: ['digit market specialist highlight strong digit market experi use social media platform profici follow program tool applic slack googl analyt adword site catalyst omnitur adob analyt microsoft excel word appl page number adob creativ photoshop lightroom illustr final cut pro avid mail chimp constant contact work zone mind jet salesforc gitlab github cv wordpress dreamweav experi compani name januari current digit market specialist citi state strateg manag use expertis interpret e commerc merchant object data insight digit market requir digit plan push think custom merchant project integr search market broader digit market channel perform advanc acquisit lead gener initi appli analyt technic skill problem solv iter campaign observ follow e commerc technolog trend resourc emerg marketplac analyz interpret raw data point uncov new busi opportun interpret chart spreadsheet present creat market opportun identifi need opportun develop action plan address abl think strateg tactic develop appropri project plan timelin coordin negoti project plan team member depart ensur project complet accuraci frequent updat senior manag project progress digit oper identifi process improv across plan account manag goal optim busi oper work independ minimum supervis demonstr digit expertis guid user best practic teach leverag system function effort introduc busi effici design content architectur layout facilit respons site ensur site optim cross platform cross browser compat custom feedback experi subject matter expert sme possess strong organiz time manag skill drive task complet develop demand gener strategi manag market program drive demand cross border product digit agil excel collabor environ come idea contribut convers quick think solut build solid effect work relationship other facilit particip group interact ad brainstorm build idea relat individu nurtur talent central effect work togeth construct work stress pressur face high workload deadlin abl adjust readili chang adapt need abil express idea clearli convey necessari inform interact effect level manag maintain posit attitud face critic reject failur servic market intellig expert cross border audienc competit sens humor help make collabor fun provid subject matter expertis usabl fedex com style guid adher across websit web applic email market autom code manag email market market autom program includ set schedul test tag deploy one time recur trigger campaign troubleshoot technic issu relat integr templat list segment lead score grade aspect market autom execut requir recogn attend import detail accuraci effici tool program bronto softwar dreamweav sublim text search engin market perform keyword research use page search engin optim seo research analyz competitor develop implement link build strategi collabor develop team ensur ppc seo best practic follow perform analysi seo strategi site keyword convers perform traffic target goal improv convers rate tool program adob analyt omnitur site catalyst googl analyt observepoint new relic googl adword digit pr identifi opportun digit market pr effort highlight editori product brand stori creat content market initi strateg allianc merchant global effort great network skill confid coordin key busi stakehold go market sale creat collater sale forc go market messag posit competit differenti develop sale tool support sell process plan launch new product releas product version updat manag cross function implement plan across team analysi insight conduct report detail analys understand perform market user experi content evalu campaign progress bottom line impact roi custom insight lead optim recommend iter improv monitor speed applic increas digit user experi dux tool profession practic observepoint b', 'test usertest com new relic manag websit updat site skeleton along maintain brand continu throughout digit web page analyt tool custom interact adob analyt omnitur site catalyst dreamweav html parallel tortois new relic adob experi manag aem ...
#
# cv_index=  1957
# CV 4 (Similarity Score: 0.969329833984375):
# Category: HR
# File Name: 18557164.pdf
# ...
#
# cv_index=  1155
# CV 2 (Similarity Score: 0.9713016748428345):
# Category: CONSULTANT
# File Name: 14517953.pdf
# Resume Text: ['consult summari job titl number year experi plan develop implement program process experienc manag excel client project manag skill action orient strong abil commun effect technolog execut busi audienc high level client interact util extens knowledg experi retir compens field resourc respons result orient season self direct servic driven skill strateg superior talent versatil well qualifi adapt ambiti analyt articul award win busi savvi client focus commit conscienti consist creativ custom focus custom servic focus deadlin driven deadlin orient dedic depend detail orient disciplin driven dynam effect energet experi expert flexibl focus gift hand hardwork highli motiv high perform innov matur meticul motiv multi task orient organ outstand perform driven person posit pragmat proactiv product profici reliabl accomplishedhighli qualifi detail orient hardwork job titl number year experi profici research write case manag client relat expert comput technolog skill includ compet multipl softwar applic websit design html cm host network issu social media highlight cost benefit analysi cba account reconcili organ unsurpass work ethic result orient skill product improv microsoft offic suit expert work flow plan detail orient superb time manag experi consult januari august compani name citi state plan design implement retir compens program vari size scope provid technic consult servic qualifi non qualifi retir compens incent plan issu client consult prepar plan document amend summari plan descript employe meet materi retir incent compens program implement polici procedur administ execut compens program design multipl cost account tax model assist client select program altern perform variou market analys client determin competit market area compens benefit primari administr consult januari januari compani name citi state administ multipl client defin contribut retir plan prepar file ir form seri report prepar requir plan complianc test includ adp acp test top heavi test annual addit test minimum coverag test requir discrimin test implement system autom multipl job function consist exceed target fee realiz ratio client relationship treasuri analyst januari januari compani name citi state design maintain cash collect disburs system manag short term cash debt balanc daili bank relationship manag execut wire transfer foreign exchang transact prepar financi report develop spreadsheet program financi model forecast provid inform system support treasuri depart pension analyst januari januari compani name citi state assist select review plan truste invest manag record keeper actuari monitor perform activ compani domest defin benefit defin contribut pension plan act liaison plan truste record keeper actuari intern benefit depart respond particip question plan invest complet annual report intern revenu servic depart labor secur exchang commiss pension benefit guarante corpor prepar annual board report global pension plan perform intern januari januari compani name citi state', 'reconcil trust bank statement record keeper account monitor perform retir plan invest manag prepar maintain quarterli invest perform report alloc insur claim plant locat educ master busi administr administr univers toledo citi state gpa gpa bachelor busi administr financ univers toledo citi state gpa gpa dean list select one st ursula academi citi state gpa gpa graduat highest honor top class nation honor societi skill account adp autom benefit consult cost crystal report client client financi model financi report forecast foreign exchang novel groupwis inform system insur microsoft internet explor invest market materi microsoft access microsoft excel exchang microsoft outlook express microsoft powerpoint window window nt microsoft word netscap navig oper system polici report secur spreadsheet tax treasuri writer']
#
# cv_index=  2138
# CV 3 (Similarity Score: 0.9706971049308777):
# Category: INFORMATION-TECHNOLOGY
# File Name: 52246737.pdf
# Resume Text: ['inform technolog provis technician career overview process driven goal orient inform secur leader year secur experi self motiv govern manag adept analyz remedi threat vector enterpris level bolster corpor strategi enhanc daili secur oper deliv improv optim busi protect lead geograph divers team adept problem solv risk analysi audit control establish immedi valu offer technic acumen maxim technolog invest effect implement busi strategi drive innov improv busi process expand servic technic strateg plan enabl capabl maxim multi million dollar cost save qualif busi process improv partner team creat effici cross function process elimin contract negoti cost save initi ad dn tcp ip microsoft exchang rapid vulner assess platform firewal id ip web filter proxi mail accomplish influenti chang agent focus renew qualiti initi complex sox govern complianc outstand mentor skill adept coach junior senior personnel portfolio collabor cross function interdepartment increas growth confid among team member financi polici forecast project deploy report project scope schedul provid ongo manag inform secur practic specif architectur design facilit continu organiz improv secur infrastructur analyt orient progress experi manag enterpris secur initi cultur develop appropri audit procedur polici manag sox govern complianc build risk base secur escal path track document highli train team profici manag experi enforc key sox requir throughout enterpris program manag cross function collabor coupl enterpris polici creation negoti acumen possess comprehens technic background manag experi resourc util train
ish maintain strong client relat via phone e mail person commun ensur client loyalti build long trust relationship success resolv client tax problem defend case profession correspond govern depart maxim product manag schedul file suppli overal aesthet offic educ univers california citi english b english introduct industri organiz psycholog statist social psycholog research seminar gener psycholog abnorm psycholog child develop cultur anthropolog principl sociolog colleg write certifi talent manag specialist juli januari certifi human capit growth inc talent manag talent acquisit employe select train develop perform manag team effect', 'interest interest paint canva draw art craft home decor cook foreign meal write short stori hike camp go beach dog addit inform interest interest paint canva draw art craft home decor cook foreign meal write short stori hike camp go beach dog skill art bookkeep chart cisco client client client relat databas design diagnosi e mail file financi govern hire hr leadership manag excel mail microsoft offic suit offic powerpoint word multimedia organ organiz payrol perform manag persuas progress psycholog quickbook recruit research research design sale spreadsheet statist tax tax telecommun phone content write']
#
# cv_index=  494
# CV 5 (Similarity Score: 0.9702134132385254):
# Category: ARTS
# File Name: 83338413.pdf
# Resume Text: ['field support specilist summari technolog support repres provid workstat applic support provid end user support via phone servic desk environ instal troubleshoot maintain use varieti comput system softwar peripher devic highlight network trace technic standard deliver critic thinker technic standard deliver telecommun field servic network secur network protocol profici internet technolog profici window ms offic profici effici data manag excel commun cisco router switch support ip telephoni visio analysi problem solv educ master scienc network commun manag keller graduat school manag citi state unit state america gpa master degre network commun manag concentr technolog app gpa complet data model normal process model object orient analysi creat entiti relationship diagram ms visio knowledg user interfac design bachelor scienc interdisciplinari studi concentr mathemat texa southern univers citi state unit state america gpa coursework interdisciplinari studi mathemat elementari middl school educ experi compani name citi state field support specilist current download radio alarm panel program inform new exist account respons telephon request provid real time instal quot field technician limit technic support custom enter order inform system technician upsel process payment applic troubleshoot system function relat radio registr panel program respons fail confirm request process data chang receiv via mail fax phone intern ticket informix mastermind support rep cpq matrix schedul new instal add equip order entri support system devic upgrad verifi custom contract bill accuraci captur maintain verifi custom inform painstak attent detail util conting plan system outag continu support intern custom provid site redund home heath provis technic assist group compani name citi state technic support repres custom servic role provid technic custom servic support via phone video chat custom requir assist navig troubl shoot issu may experi within intuit turbo tax product resolv custom complaint concern strong verbal negoti skill provid thorough support problem resolut custom manag setup servic request intuit turbo tax compani name citi state th grade read languag art teacher current prepar lesson reflect accommod differ student learn style', 'provid varieti plan learn experi integr differ learn method order motiv inspir student develop lesson district mission mind align district state instruct goal object subject area maintain classroom environ promot safe effect learn continu engag student parent commun member advanc student outcom establish implement effect classroom manag procedur creat system monitor assess student learn collabor profession staff identifi address student need regard health learn style avail counsel student parent school keep accur record student inform compil maintain file report record document requir school district present subject matter accord guidelin establish texa educ agenc board truste polici administr regul compani name citi state custom servic collect custom feedback made process chang exceed custom satisfact goal provid accur appropri inform respons custom inquiri demonstr masteri custom servic call script within specifi timefram address custom servic inquiri time accur fashion skill knowledg telecom industri experi way radio system satellit system fcc faa function understand wireless voip protocol wireless mobil profici network protocol tcp ip sip mgcp sccp mpl window window activ directori tcp ip network tablet technolog smartphon technolog microsoft offic profici messag technolog includ limit exchang smtp wireless technolog vpn technolog pc secur telecommun web technolog video conferenc']
